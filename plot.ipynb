# %%
import altair as alt
import pandas as pd

# %%
data = pd.read_csv("example-data.csv")

data
# Out:
#    day  consumption
# 0    1         10.5
# 1    2         12.0
# 2    3         30.0
# 3    4          5.0
# 4    5         20.5
# 5    6          5.7
# 6    7          4.5
# 7    8         35.0
# 8    9         37.0
# 9   10         20.0

# %%
alt.Chart(data).mark_bar().encode(
    alt.X("consumption:Q", bin=alt.Bin(step=2)),
    y='count()',
)
# Out:
# alt.Chart(...)
